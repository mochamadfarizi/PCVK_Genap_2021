# %% [markdown]
# <a href="https://colab.research.google.com/github/mochamadfarizi/PCVK_Genap_2021/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/gambar/mikasa-wallpaper-4k.jpg')
plt.imshow(img) # perhatikan hasilnya adalah citra dengan channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) # konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/gambar/mikasa-wallpaper-4k.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

# simpan file image
# cv.imwrite('/content/drive/MyDrive/pcvk/img/mandrill2.tiff',img5)

# tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) # ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
# perhatikan koordinat titik" pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],
                     [200,200],
                     [400,300],
                     [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# PERTANYAAN
#
#   1.Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib? Jawab :
# menurut saya, dengan adanya matplotlib bisa memudahkan dalam membuat grafik yang rapi dengan cara yg mudah dan juga bisa mengisi parameter terhadap grafik tersebut
#
#   1.Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32? Jawab :
# Int16 Ini adalah FCL type. Dalam C#, pendek dipetakan ke Int16. Ini adalah jenis nilai dan mewakili Sistem.Int16 struct.Hal ini ditandatangani dan membutuhkan 16 bit.Memiliki minimal -32768 dan maksimum +32767 nilai.
#
# Int32Ini adalah FCL type.Dalam C#, int dipetakan ke Int32.Ini adalah jenis nilai dan mewakili Sistem.Int32 struct.Hal ini ditandatangani dan membutuhkan 32 bit.Memiliki minimal -2147483648 dan maksimum +2147483647 nilai.
#
#   1.Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2)) jawab : untuk mengatur tata letak ukuran
#   1.Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut Jawab :
# Menampilkan gambar secara otomatis dari google drive tetapi warnanya berbalik menjadi BGR
#
#   1.Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3 Jawab:
# Untuk menyediakan fungsi konversi untuk gambar

# %%
# TUGAS
# nomor 1
# Red-Green
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
# Green-Blue
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
# nomor 3
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %%
# nomor 4
plt.imshow(img[5:30])

# %%
# nomor 5
img_ktk = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_ktk, pt1=(300,300), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img_ktk, pt1=(900,100), pt2=(700,200), color=(0,255,0),thickness=10)
cv.rectangle(img_ktk, pt1=(400,400), pt2=(900,300), color=(255,255,255),thickness=10)
cv.rectangle(img_ktk, pt1=(100,900), pt2=(300,400), color=(255,0,0),thickness=10)
cv.rectangle(img_ktk, pt1=(900,700), pt2=(600,550), color=(0,0,255),thickness=10)
plt.imshow(img_ktk)

# %%
# nomor 6
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %%
img_f = cv.imread('/content/drive/MyDrive/gambar/OIP.jpg')
plt.imshow(img_f)

# %%
cv.rectangle(img_f,pt1=(260,160),pt2=(1000,1500),color=(0,0,255),thickness=15)
plt.imshow(img_f)

# %%
cv.circle(img_f,center=(680,800),radius=300,color=(255,0,0),thickness=8)
plt.imshow(img_f)

# %%
img_b = cv.imread('/content/drive/MyDrive/gambar/mikasa.jpg')
plt.imshow(img_b)

# %%
img_rgb = cv.cvtColor(img_b,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
cv.rectangle(img_rgb,pt1=(100,180),pt2=(10,100),color=(0,255,0),thickness=10)
plt.imshow(img_rgb)

# %%
font = cv.FONT_HERSHEY_SCRIPT_COMPLEX
cv.putText(img_rgb,text='Ini orang cantik ',org=(20,100),fontFace=font,fontScale=2,color=(0,255,255),thickness=2,lineType=cv.LINE_AA)
plt.imshow(img_rgb)
