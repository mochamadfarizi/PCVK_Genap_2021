# %% [markdown]
# <a href="https://colab.research.google.com/github/mochamadfarizi/PCVK_Genap_2021/blob/main/project%20uas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import math
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/PCD/dataset/sampel data 1.png')
plt.imshow(img)
img.shape
# Out:
# (120, 240, 3)

# %%
img[:,:,0] #blue
# Out:
# array([[35, 35, 38, ..., 87, 90, 89],
#        [49, 41, 36, ..., 84, 84, 84],
#        [54, 48, 48, ..., 85, 86, 85],
#        ...,
#        [18, 17, 18, ..., 65, 67, 66],
#        [17, 18, 17, ..., 64, 62, 61],
#        [18, 17, 17, ..., 71, 66, 65]], dtype=uint8)

# %%
img[:,:,1] #green
# Out:
# array([[51, 51, 52, ..., 89, 92, 91],
#        [61, 54, 49, ..., 86, 86, 86],
#        [64, 59, 60, ..., 87, 88, 88],
#        ...,
#        [21, 20, 21, ..., 66, 68, 67],
#        [20, 21, 20, ..., 65, 63, 62],
#        [21, 20, 20, ..., 72, 67, 66]], dtype=uint8)

# %%
img[:,:,2] #red
# Out:
# array([[54, 54, 55, ..., 83, 86, 85],
#        [63, 56, 51, ..., 80, 80, 80],
#        [66, 61, 62, ..., 81, 82, 82],
#        ...,
#        [19, 18, 19, ..., 62, 64, 63],
#        [18, 19, 18, ..., 61, 59, 58],
#        [19, 18, 18, ..., 68, 63, 62]], dtype=uint8)

# %%
hasil = []

for x in range(0,img.shape[0]):
    row = []
    for y in range(0, img.shape[1]):
        blue = img[x,y,0] - 35
        green = img[x,y,1] - 35
        red = img[x,y,2] - 160
        blue = blue**2
        green = green**2
        red = red**2
        tambahRGB = blue + green + red
        akar = math.sqrt(tambahRGB)
        if akar > 55:
            row.append(0)
        else:
            row.append(255)
    hasil.append(row)

# %%
segar = True
for i in hasil:
    for j in i:
        if j > 0:
            segar = False
            break;

# %%
if segar:
    print("ikan Segar")
else:
    print("ikan Tidak Segar")
# Out:
# ikan Segar
